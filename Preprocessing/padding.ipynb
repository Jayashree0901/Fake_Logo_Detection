# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/Ariel'
output_folder = '/content/drive/MyDrive/padding/Ariel'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/adidas'
output_folder = '/content/drive/MyDrive/padding/adidas'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/apple'
output_folder = '/content/drive/MyDrive/padding/apple'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/baskin_robbins'
output_folder = '/content/drive/MyDrive/padding/baskin_robbins'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/cocacola'
output_folder = '/content/drive/MyDrive/padding/cocacola'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/Colgate'
output_folder = '/content/drive/MyDrive/padding/Colgate'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/DELL'
output_folder = '/content/drive/MyDrive/padding/DELL'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/lloyd'
output_folder = '/content/drive/MyDrive/padding/lloyd'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/nike'
output_folder = '/content/drive/MyDrive/padding/nike'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/PONDS'
output_folder = '/content/drive/MyDrive/padding/PONDS'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/Renault'
output_folder = '/content/drive/MyDrive/padding/Renault'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/proj/vans'
output_folder = '/content/drive/MyDrive/padding/vans'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/Fake_Logos/Jaguar'
output_folder = '/content/drive/MyDrive/padding/Jaguar'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/Fake_Logos/Lotus'
output_folder = '/content/drive/MyDrive/padding/Lotus'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/proj/Calvin_Klein'
output_folder = '/content/drive/MyDrive/padding/Calvin_Klein'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/Fake_Logos/IFA'
output_folder = '/content/drive/MyDrive/padding/IFA'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/Fake_Logos/JPMorgan'
output_folder = '/content/drive/MyDrive/padding/JPMorgan'
padding = 20 

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/Fake_Logos/lacto'
output_folder = '/content/drive/MyDrive/padding/lacto'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/Fake_Logos/Packman'
output_folder = '/content/drive/MyDrive/padding/Packman'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)

# %%
from PIL import Image, ImageOps
import os

def add_padding_to_folder(input_folder, output_folder, padding):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    for filename in os.listdir(input_folder):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            image_path = os.path.join(input_folder, filename)
            image = Image.open(image_path)

            padded_image = ImageOps.expand(image, border=padding, fill='white')

            output_path = os.path.join(output_folder, filename)
            padded_image.save(output_path)

            print(f"Added padding to {filename} and saved to {output_path}")

input_folder = '/content/drive/MyDrive/Dataset/Fake_Logos/hulk'
output_folder = '/content/drive/MyDrive/padding/hulk'
padding = 20  

add_padding_to_folder(input_folder, output_folder, padding)
